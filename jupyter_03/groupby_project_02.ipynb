# %% [markdown]
# ## Change the data frame to a form more convenient for processing

# %%
import pandas as pd

# %%
chicago = pd.read_csv("chicago.csv", index_col = "Name").dropna(how = "all")
chicago.head(3)
# Out:
#                      Position Title   Department Employee Annual Salary
# Name
# AARON,  ELVIA J    WATER RATE TAKER  WATER MGMNT              $90744.00
# AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# AARON,  KARINA       POLICE OFFICER       POLICE              $84450.00

# %%
chicago.index.names = ["NAME"]

# %%
chicago.rename(columns = {"Position Title":"POSITION","Department":"DEPARTMENT","Employee Annual Salary":"SALARY"}, inplace = True)

# %%
chicago.head(3)
# Out:
#                            POSITION   DEPARTMENT     SALARY
# NAME
# AARON,  ELVIA J    WATER RATE TAKER  WATER MGMNT  $90744.00
# AARON,  JEFFERY M    POLICE OFFICER       POLICE  $84450.00
# AARON,  KARINA       POLICE OFFICER       POLICE  $84450.00

# %%
chicago.index = chicago.index.str.strip().str.title()
chicago.tail(3)
# Out:
#                                     POSITION DEPARTMENT      SALARY
# NAME
# Zymantas,  Mark E             POLICE OFFICER     POLICE   $84450.00
# Zyrkowski,  Carlo E           POLICE OFFICER     POLICE   $87384.00
# Zyskowski,  Dariusz  CHIEF DATA BASE ANALYST       DoIT  $113664.00

# %%
for col in chicago.columns:
    chicago[col] = chicago[col].str.strip().str.title()
chicago.tail(3)
# Out:
#                                     POSITION DEPARTMENT      SALARY
# NAME
# Zymantas,  Mark E             Police Officer     Police   $84450.00
# Zyrkowski,  Carlo E           Police Officer     Police   $87384.00
# Zyskowski,  Dariusz  Chief Data Base Analyst       Doit  $113664.00

# %%
chicago["SALARY"] = chicago["SALARY"].str.replace("$", "").astype(float)

# %%
chicago.head(3)
# Out:
#                            POSITION   DEPARTMENT   SALARY
# NAME
# Aaron,  Elvia J    Water Rate Taker  Water Mgmnt  90744.0
# Aaron,  Jeffery M    Police Officer       Police  84450.0
# Aaron,  Karina       Police Officer       Police  84450.0

# %% [markdown]
# ## Group by DEPARTMENT and list the highest paid people by group

# %%
chicago.nunique()
# Out:
# POSITION      1093
# DEPARTMENT      35
# SALARY        1156
# dtype: int64

# %%
departments = chicago.groupby("DEPARTMENT")

# %%
df = pd.DataFrame(columns = chicago.columns)

# %%
for department, data in departments:
    highest = data.nlargest(1,"SALARY")
    df = pd.concat(objs = [df, pd.DataFrame(highest)])
df
# Out:
# /var/folders/1q/k4l8fhs1713bq3tphgfwt39m0000gn/T/ipykernel_1738/2520803209.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(objs = [df, pd.DataFrame(highest)])
#                                                               POSITION  \
# Jackowiak,  Patricia                    Dir Of Administrative Hearings
# Yamaji,  Peter S                                          Veterinarian
# Evans,  Ginger S                              Commissioner Of Aviation
# Bateman,  Kelly Anne               Deputy Chief Administrative Officer
# Berlin,  Steven                        Executive Dir - Board Of Ethics
# Holt,  Alexandra D                                          Budget Dir
# Frydland,  Judith                            Commissioner Of Buildings
# Guerra,  Maria            Commissioner Of Bus Afairs And Consumer Prot
# Mendoza,  Susana A                                          City Clerk
# Kaiden,  Marla M                          Chief Administrative Officer
# Reifman,  David                 Commissioner Of Planning & Development
# Boone,  Michelle T        Commissioner Of Cultural Affairs/Spec Events
# Tamley,  Karen M                 Comm Mayors Off People W Disabilities
# Berman,  Brenna M                            Chief Information Officer
# Morrison Butler,  Lisa V   Commissioner Of Family And Support Services
# Widawsky,  Daniel J                                   City Comptroller
# Santiago,  Jose A                                    Fire Commissioner
# Reynolds,  David J         Commissioner Of Fleet & Facility Management
# Morita,  Julia Y                                Commissioner Of Health
# Noriega,  Mona             Chairperson - Commission On Human Relations
# Choi,  Soo                             Commissioner Of Human Resources
# Ferguson,  Joseph M                                  Inspector General
# Fairley,  Sharon R                                 Chief Administrator
# Patton,  Stephen R                                 Corporation Counsel
# Guzman Flores,  Michelle                                    Staff Asst
# Emanuel,  Rahm                                                   Mayor
# Schenkel,  Gary W                           Exec Dir Emerg Mgmt & Comm
# Escalante,  John J                         First Deputy Superintendent
# Caproni,  Max A                           Executive Dir - Police Board
# Rhee,  Jamie L                               Chief Procurement Officer
# Bannon,  Brian A                Commissioner Of Chicago Public Library
# Williams,  Charles L            Commissioner Of Streets And Sanitation
# Scheinfeld,  Rebekah C                  Commissioner Of Transportation
# Lafleur,  Kristi L                               Deputy City Treasurer
# Powers,  Thomas H                           Commissioner Of Water Mgmt
#
#                                      DEPARTMENT    SALARY
# Jackowiak,  Patricia               Admin Hearng  156420.0
# Yamaji,  Peter S                  Animal Contrl  123144.0
# Evans,  Ginger S                       Aviation  300000.0
# Bateman,  Kelly Anne          Board Of Election  129840.0
# Berlin,  Steven                 Board Of Ethics  131688.0
# Holt,  Alexandra D                Budget & Mgmt  169992.0
# Frydland,  Judith                     Buildings  157092.0
# Guerra,  Maria                 Business Affairs  157092.0
# Mendoza,  Susana A                   City Clerk  133545.0
# Kaiden,  Marla M                   City Council  160248.0
# Reifman,  David           Community Development  175020.0
# Boone,  Michelle T             Cultural Affairs  155040.0
# Tamley,  Karen M                   Disabilities  138420.0
# Berman,  Brenna M                          Doit  154992.0
# Morrison Butler,  Lisa V       Family & Support  175002.0
# Widawsky,  Daniel J                     Finance  165000.0
# Santiago,  Jose A                          Fire  202728.0
# Reynolds,  David J             General Services  157092.0
# Morita,  Julia Y                         Health  177000.0
# Noriega,  Mona                  Human Relations  125004.0
# Choi,  Soo                      Human Resources  151572.0
# Ferguson,  Joseph M               Inspector Gen  161856.0
# Fairley,  Sharon R                         Ipra  161856.0
# Patton,  Stephen R                          Law  173664.0
# Guzman Flores,  Michelle      License Appl Comm   71292.0
# Emanuel,  Rahm                   Mayor'S Office  216210.0
# Schenkel,  Gary W                          Oemc  167796.0
# Escalante,  John J                       Police  197724.0
# Caproni,  Max A                    Police Board   97728.0
# Rhee,  Jamie L                      Procurement  167220.0
# Bannon,  Brian A                 Public Library  167004.0
# Williams,  Charles L              Streets & San  157092.0
# Scheinfeld,  Rebekah C               Transportn  169500.0
# Lafleur,  Kristi L                    Treasurer  150000.0
# Powers,  Thomas H                   Water Mgmnt  169512.0
