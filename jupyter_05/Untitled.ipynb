# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Crime_Data_from_2020_to_Present.csv")
df["Date Rptd"] = pd.to_datetime(df["Date Rptd"])
df["DATE OCC"] = pd.to_datetime(df["DATE OCC"])
df.head()
# Out:
# /var/folders/1q/k4l8fhs1713bq3tphgfwt39m0000gn/T/ipykernel_27780/811371206.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date Rptd"] = pd.to_datetime(df["Date Rptd"])
# /var/folders/1q/k4l8fhs1713bq3tphgfwt39m0000gn/T/ipykernel_27780/811371206.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["DATE OCC"] = pd.to_datetime(df["DATE OCC"])
#        DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA  AREA NAME  Rpt Dist No  \
# 0  190326475 2020-03-01 2020-03-01      2130     7   Wilshire          784
# 1  200106753 2020-02-09 2020-02-08      1800     1    Central          182
# 2  200320258 2020-11-11 2020-11-04      1700     3  Southwest          356
# 3  200907217 2023-05-10 2020-03-10      2037     9   Van Nuys          964
# 4  220614831 2022-08-18 2020-08-17      1200     6  Hollywood          666
#
#    Part 1-2  Crm Cd                               Crm Cd Desc  ... Status  \
# 0         1     510                          VEHICLE - STOLEN  ...     AA
# 1         1     330                     BURGLARY FROM VEHICLE  ...     IC
# 2         1     480                             BIKE - STOLEN  ...     IC
# 3         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4         2     354                         THEFT OF IDENTITY  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest    510.0    998.0       NaN      NaN
# 1   Invest Cont    330.0    998.0       NaN      NaN
# 2   Invest Cont    480.0      NaN       NaN      NaN
# 3   Invest Cont    343.0      NaN       NaN      NaN
# 4   Invest Cont    354.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 2   1400 W  37TH                         ST          NaN  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                         1900    TRANSIENT          NaN  34.0944 -118.3277
#
# [5 rows x 28 columns]

# %%
df = df.rename(columns = {'Date Rptd':'Date-1','DATE OCC':'Date-2'})
df.tail()
# Out:
#             DR_NO     Date-1     Date-2  TIME OCC  AREA AREA NAME  \
# 892929  241604405 2024-01-14 2024-01-13       720    16  Foothill
# 892930  241604246 2024-01-08 2024-01-08       800    16  Foothill
# 892931  242004546 2024-01-16 2024-01-16      1510    20   Olympic
# 892932  240705409 2024-02-02 2024-01-31        30     7  Wilshire
# 892933  240104953 2024-01-15 2024-01-15       100     1   Central
#
#         Rpt Dist No  Part 1-2  Crm Cd  \
# 892929         1673         1     230
# 892930         1601         2     625
# 892931         2013         2     624
# 892932          784         1     510
# 892933          101         2     745
#
#                                            Crm Cd Desc  ... Status  \
# 892929  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 892930                                   OTHER ASSAULT  ...     IC
# 892931                        BATTERY - SIMPLE ASSAULT  ...     IC
# 892932                                VEHICLE - STOLEN  ...     IC
# 892933        VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
#
#         Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 892929  Invest Cont    230.0      NaN       NaN      NaN
# 892930  Invest Cont    625.0      NaN       NaN      NaN
# 892931  Invest Cont    624.0      NaN       NaN      NaN
# 892932  Invest Cont    510.0      NaN       NaN      NaN
# 892933  Invest Cont    745.0      NaN       NaN      NaN
#
#                                        LOCATION  \
# 892929  8700    LANKERSHIM                   BL
# 892930          VAUGHN                       ST
# 892931          HOBART                       BL
# 892932  2300 S  SYCAMORE                     AV
# 892933  1300 W  SUNSET                       BL
#
#                            Cross Street      LAT       LON
# 892929                              NaN  34.2271 -118.3878
# 892930  DE GARMO                     AV  34.2865 -118.4161
# 892931  3RD                          ST  34.0690 -118.3054
# 892932                              NaN  34.0360 -118.3527
# 892933                              NaN  34.0685 -118.2460
#
# [5 rows x 28 columns]
