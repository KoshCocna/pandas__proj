# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime_raw_data = pd.read_csv("Crime_Data_from_2020_to_Present.csv")
crime_raw_data
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 892929  241604405  01/14/2024 12:00:00 AM  01/13/2024 12:00:00 AM       720
# 892930  241604246  01/08/2024 12:00:00 AM  01/08/2024 12:00:00 AM       800
# 892931  242004546  01/16/2024 12:00:00 AM  01/16/2024 12:00:00 AM      1510
# 892932  240705409  02/02/2024 12:00:00 AM  01/31/2024 12:00:00 AM        30
# 892933  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
#
# ...

# %%
crime_data = crime_raw_data[['DATE OCC','AREA NAME', 'Crm Cd Desc', 'Status Desc', 'LOCATION']]

# %%
crime_data.set_index("DATE OCC", inplace = True)

# %%
crime_data
# Out:
#                         AREA NAME  \
# DATE OCC
# 03/01/2020 12:00:00 AM   Wilshire
# 02/08/2020 12:00:00 AM    Central
# 11/04/2020 12:00:00 AM  Southwest
# 03/10/2020 12:00:00 AM   Van Nuys
# 08/17/2020 12:00:00 AM  Hollywood
# ...                           ...
# 01/13/2024 12:00:00 AM   Foothill
# 01/08/2024 12:00:00 AM   Foothill
# 01/16/2024 12:00:00 AM    Olympic
# 01/31/2024 12:00:00 AM   Wilshire
# 01/15/2024 12:00:00 AM    Central
#
#                                                            Crm Cd Desc  \
# DATE OCC
# 03/01/2020 12:00:00 AM                                VEHICLE - STOLEN
# 02/08/2020 12:00:00 AM                           BURGLARY FROM VEHICLE
# 11/04/2020 12:00:00 AM                                   BIKE - STOLEN
# 03/10/2020 12:00:00 AM        SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 08/17/2020 12:00:00 AM                               THEFT OF IDENTITY
# ...                                                                ...
# ...

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 892934 entries, 03/01/2020 12:00:00 AM to 01/15/2024 12:00:00 AM
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   AREA NAME    892934 non-null  object
#  1   Crm Cd Desc  892934 non-null  object
#  2   Status Desc  892934 non-null  object
#  3   LOCATION     892934 non-null  object
# dtypes: object(4)
# memory usage: 34.1+ MB

# %%
crime_data.nunique()
# Out:
# AREA NAME         21
# Crm Cd Desc      139
# Status Desc        6
# LOCATION       64914
# dtype: int64

# %%
order = crime_data["AREA NAME"].unique().tolist()
order
# Out:
# ['Wilshire',
#  'Central',
#  'Southwest',
#  'Van Nuys',
#  'Hollywood',
#  'Southeast',
#  'Newton',
#  'Mission',
#  'Rampart',
#  'Hollenbeck',
#  'West Valley',
#  'West LA',
#  'Olympic',
#  'Topanga',
#  'Northeast',
#  '77th Street',
#  'Pacific',
#  'N Hollywood',
#  'Harbor',
#  'Foothill',
#  'Devonshire']

# %%
# order2 = []
# for i in range(len(order)):
#     order2.append(i)
# type(order2)
# Out:
# list

# %%
ax= sns.countplot(x = "AREA NAME", data = crime_data, order = order)
ax.set_xticks(range(len(order)), labels=range(0, len(order)))
# Out:
# /Users/kskim/miniconda3/envs/ws/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/kskim/miniconda3/envs/ws/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
